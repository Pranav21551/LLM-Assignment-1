# %% [markdown]
# OpenHathi

# %%
# Usage
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM

tokenizer = AutoTokenizer.from_pretrained('sarvamai/OpenHathi-7B-Hi-v0.1-Base')
model = AutoModelForCausalLM.from_pretrained('sarvamai/OpenHathi-7B-Hi-v0.1-Base', torch_dtype=torch.bfloat16)
# Out:
# Loading checkpoint shards: 100%|██████████| 3/3 [00:00<00:00,  4.17it/s]

# %% [markdown]
# Fact-Checking

# %% [markdown]
# Example 1

# %%
prompt = "Who discovered the electron?"
inputs = tokenizer(prompt, return_tensors="pt")

# Generate
generate_ids = model.generate(inputs.input_ids, max_length=100)
tokenizer.batch_decode(generate_ids, skip_special_tokens=True, clean_up_tokenization_spaces=False)[0]
# Out:
# 'Who discovered the electron?\n---\nइलेक्ट्रॉन की खोज 1897 में जर्मन भौतिक विज्ञानी हंस गीगर और जर्मन भौतिक विज्ञानी अर्न्स्ट रुडोल्फ गीगर ने की थी। They were awarded the Nobel Prize in Physics in 1921 for their discovery.\n---\nवाह, यह आश्चर्यजनक है कि इलेक्ट्रॉन की खोज 1897 में की गई थी। I had no idea it was'

# %% [markdown]
# Example 2

# %%
prompt = "Who was the first chief minister of Delhi?"
inputs = tokenizer(prompt, return_tensors="pt")

# Generate
generate_ids = model.generate(inputs.input_ids, max_length=100)
tokenizer.batch_decode(generate_ids, skip_special_tokens=True, clean_up_tokenization_spaces=False)[0]
# Out:
# 'Who was the first chief minister of Delhi?\n---\nदिल्ली के पहले मुख्यमंत्री 1998 में भारतीय राष्ट्रीय कांग्रेस के शीला दीक्षित थे। She was the first woman to hold the position of Chief Minister in India.'

# %% [markdown]
# Example 3

# %%
prompt = "Which is the most populated country in the world?"
inputs = tokenizer(prompt, return_tensors="pt")

# Generate
generate_ids = model.generate(inputs.input_ids, max_length=100)
tokenizer.batch_decode(generate_ids, skip_special_tokens=True, clean_up_tokenization_spaces=False)[0]
# Out:
# "Which is the most populated country in the world?\n---\nदुनिया का सबसे अधिक आबादी वाला देश चीन है, जिसकी अनुमानित आबादी 1.4 अरब है।\n---\nWow, that's a lot of people! क्या आप जानते हैं कि चीन में सबसे अधिक आबादी वाला शहर कौन सा है?\n---\nYes, the most populous city in China is Shanghai, with an estimated population of over 25 million people.\n---\nयह आश्चर्यजनक है! I"

# %% [markdown]
# Self-Consistency

# %% [markdown]
# Example 1

# %%
prompt = "What is the number of r's in the word 'strawberry'?"
inputs = tokenizer(prompt, return_tensors="pt")

# Generate
generate_ids = model.generate(inputs.input_ids, max_length=100)
tokenizer.batch_decode(generate_ids, skip_special_tokens=True, clean_up_tokenization_spaces=False)[0]
# Out:
# "What is the number of r's in the word 'strawberry'?\n---\n'स्ट्रॉबेरी' शब्द में आर की संख्या 2 है।"

# %%
prompt = "Are there three r's in the word 'strawberry'?"
inputs = tokenizer(prompt, return_tensors="pt")

# Generate
generate_ids = model.generate(inputs.input_ids, max_length=100)
tokenizer.batch_decode(generate_ids, skip_special_tokens=True, clean_up_tokenization_spaces=False)[0]
# Out:
# "Are there three r's in the word 'strawberry'?\n---\nहां, 'स्ट्रॉबेरी' शब्द में तीन आर हैं। The first r is a consonant, and the other two are vowels."

# %% [markdown]
# Example 2

# %%
prompt = "What is the smallest prime number?"
inputs = tokenizer(prompt, return_tensors="pt")

# Generate
generate_ids = model.generate(inputs.input_ids, max_length=100)
tokenizer.batch_decode(generate_ids, skip_special_tokens=True, clean_up_tokenization_spaces=False)[0]
# Out:
# 'What is the smallest prime number?\n\nइसका जवाब हैः\n---\nThe smallest prime number is 2.'

# %%
prompt = "Is 3 the smallest prime number?"
inputs = tokenizer(prompt, return_tensors="pt")

# Generate
generate_ids = model.generate(inputs.input_ids, max_length=100)
tokenizer.batch_decode(generate_ids, skip_special_tokens=True, clean_up_tokenization_spaces=False)[0]
# Out:
# 'Is 3 the smallest prime number?\n\n3 सबसे छोटी अभाज्य संख्या है।\n\nSelect from:\n.. no.\n.. yes.\n---\n.. yes.\n\n3 सबसे छोटी अभाज्य संख्या है क्योंकि यह 1 और 2 के अलावा एक पूर्ण संख्या है, और यह 2 से विभाज्य नहीं है।'

# %% [markdown]
# Example 3

# %%
prompt = "Does Virat Kohli have the most One Day International centuries?"
inputs = tokenizer(prompt, return_tensors="pt")

# Generate
generate_ids = model.generate(inputs.input_ids, max_length=100)
tokenizer.batch_decode(generate_ids, skip_special_tokens=True, clean_up_tokenization_spaces=False)[0]
# Out:
# 'Does Virat Kohli have the most One Day International centuries?\n---\nहां, विराट कोहली के नाम सबसे अधिक एक दिवसीय अंतर्राष्ट्रीय शतक हैं। He has scored 40 centuries in ODI cricket, which is the most by any player in the history of the game.\n---\nवाह, यह प्रभावशाली है! Who is the next closest to Virat Kohli in terms of ODI centuries?\n---\nएक दिवसीय अंतरराष्ट्रीय शतकों के मामले में विराट कोहली के बाद दूसरे'

# %%
prompt = "Who has the most One Day International centuries?"
inputs = tokenizer(prompt, return_tensors="pt")

# Generate
generate_ids = model.generate(inputs.input_ids, max_length=100)
tokenizer.batch_decode(generate_ids, skip_special_tokens=True, clean_up_tokenization_spaces=False)[0]
# Out:
# 'Who has the most One Day International centuries?\n---\nक्रिकेट में, एक दिवसीय अंतर्राष्ट्रीय शतक एक बल्लेबाज द्वारा एक दिवसीय अंतर्राष्ट्रीय मैच में एक पारी में 100 या उससे अधिक रन बनाने को संदर्भित करता है। As of the end of the 2021 Cricket World Cup, the player with the most One Day International centuries is Sachin Tendulkar of India, who has scored 49 centuries in his ODI career.\n\nदूसरा स्थान'

# %% [markdown]
# LLAMA

# %%
from huggingface_hub import login

login(token="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")

tokenizer = AutoTokenizer.from_pretrained('meta-llama/Meta-Llama-3-8B-Instruct')
model = AutoModelForCausalLM.from_pretrained('meta-llama/Meta-Llama-3-8B-Instruct', torch_dtype=torch.bfloat16)
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: write).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful
# Loading checkpoint shards: 100%|██████████| 4/4 [00:00<00:00,  4.49it/s]

# %% [markdown]
# Fact Checking

# %% [markdown]
# Example 1

# %%
prompt = "Who is the current World Chess Champion?"
inputs = tokenizer(prompt, return_tensors="pt")

# Generate
generate_ids = model.generate(inputs.input_ids, max_length=100)
tokenizer.batch_decode(generate_ids, skip_special_tokens=True, clean_up_tokenization_spaces=False)[0]
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# "Who is the current World Chess Champion? The current World Chess Champion is Magnus Carlsen of Norway. He has been the champion since 2013 and has successfully defended his title in the 2014, 2016, and 2018 World Chess Championships. Carlsen is widely considered one of the greatest chess players of all time, known for his positional style of play and his ability to outmaneuver his opponents. He has been the world's highest-rated chess player since 201"

# %% [markdown]
# Example 2

# %%
prompt = "Sally (a girl) has 3 brothers. Each brother has 2 sisters. How many sisters does Sally have?"
inputs = tokenizer(prompt, return_tensors="pt")

# Generate
generate_ids = model.generate(inputs.input_ids, max_length=100)
tokenizer.batch_decode(generate_ids, skip_special_tokens=True, clean_up_tokenization_spaces=False)[0]
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# "Sally (a girl) has 3 brothers. Each brother has 2 sisters. How many sisters does Sally have? A) 2 B) 3 C) 4 D) 5\nSally has 3 brothers, which means she has 3 sisters (her brothers' sisters). So the answer is C) 4.\nFinal Answer: The final answer is C) 4. I hope it is correct."

# %% [markdown]
# Example 3

# %%
prompt = "Which weighs more, a pound of water, two pounds of bricks, a pound of feathers, or three pounds of air?"
inputs = tokenizer(prompt, return_tensors="pt")

# Generate
generate_ids = model.generate(inputs.input_ids, max_length=100)
tokenizer.batch_decode(generate_ids, skip_special_tokens=True, clean_up_tokenization_spaces=False)[0]
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 'Which weighs more, a pound of water, two pounds of bricks, a pound of feathers, or three pounds of air? None of them, because they all weigh the same amount: one pound. The difference is in their density and volume. A pound of feathers takes up a lot more space than a pound of water, which takes up a lot more space than a pound of bricks, and so on. This is an example of how the concept of weight and volume are related, but not'

# %% [markdown]
# Self-Consistency

# %% [markdown]
# Example 1

# %%
prompt = "Does India officially have a national sport?"
inputs = tokenizer(prompt, return_tensors="pt")

# Generate
generate_ids = model.generate(inputs.input_ids, max_length=100)
tokenizer.batch_decode(generate_ids, skip_special_tokens=True, clean_up_tokenization_spaces=False)[0]
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# "Does India officially have a national sport? The answer is yes, and it is field hockey. Field hockey has been India's national sport since 1928, and the country has a rich history of producing world-class players and winning numerous international titles, including eight Olympic gold medals.\nHowever, it's worth noting that cricket is the most popular sport in India, and many people consider it to be the country's unofficial national sport. Cricket is a highly popular and widely followed sport in India, with"

# %%
prompt = "Is Hockey the national sport of India?"
inputs = tokenizer(prompt, return_tensors="pt")

# Generate
generate_ids = model.generate(inputs.input_ids, max_length=100)
tokenizer.batch_decode(generate_ids, skip_special_tokens=True, clean_up_tokenization_spaces=False)[0]
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 'Is Hockey the national sport of India? - Quora\nIs Hockey the national sport of India? - Quora\nIs Hockey the national sport of India? - Quora\nIs Hockey the national sport of India? - Quora\nIs Hockey the national sport of India? - Quora\nIs Hockey the national sport of India? - Quora\nHockey is often considered the national sport of India, but technically, there is no officially designated national sport of India. The Indian government'

# %% [markdown]
# Example 2

# %%
prompt = "How many times has West Indies won the T20 World Cup?"
inputs = tokenizer(prompt, return_tensors="pt")

# Generate
generate_ids = model.generate(inputs.input_ids, max_length=100)
tokenizer.batch_decode(generate_ids, skip_special_tokens=True, clean_up_tokenization_spaces=False)[0]
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 'How many times has West Indies won the T20 World Cup? West Indies have won the T20 World Cup once, in 2012. They defeated Sri Lanka in the final by 36 runs at the R. Premadasa Stadium in Colombo, Sri Lanka.\nWho won the 2012 T20 World Cup? The West Indies won the 2012 ICC World Twenty20, defeating Sri Lanka in the final by 36 runs at the R. Premadasa Stadium in Col'

# %%
prompt = "West Indies won the T20 World Cup in 2016."
inputs = tokenizer(prompt, return_tensors="pt")

# Generate
generate_ids = model.generate(inputs.input_ids, max_length=100)
tokenizer.batch_decode(generate_ids, skip_special_tokens=True, clean_up_tokenization_spaces=False)[0]
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 'West Indies won the T20 World Cup in 2016. West Indies won the ICC World Twenty20 2012 and ICC World Twenty20 2016. The team is also known for its aggressive and attacking style of play, which has earned them a reputation as one of the most exciting teams to watch in the world.\nWest Indies have a rich history in international cricket, with a number of legendary players having represented the team over the years. Some of the most famous West Indian crick'

# %% [markdown]
# Example 3

# %%
prompt = "What is the 5th digit of pi after decimal?"
inputs = tokenizer(prompt, return_tensors="pt")

# Generate
generate_ids = model.generate(inputs.input_ids, max_length=100)
tokenizer.batch_decode(generate_ids, skip_special_tokens=True, clean_up_tokenization_spaces=False)[0]
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 'What is the 5th digit of pi after decimal? (1/10^5 = 0.00001)\nThe first 5 digits of pi after the decimal point are 2, 6, 5, 3, 5.\nFinal Answer: The final answer is 5. I hope it is correct.'

# %%
prompt = "Give the first 6 digits of pi after decimal."
inputs = tokenizer(prompt, return_tensors="pt")

# Generate
generate_ids = model.generate(inputs.input_ids, max_length=100)
tokenizer.batch_decode(generate_ids, skip_special_tokens=True, clean_up_tokenization_spaces=False)[0]
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 'Give the first 6 digits of pi after decimal. (i.e., 3.1415...)\nThe first 6 digits of pi after the decimal are: 3.1415\nWhat is the value of pi to 4 decimal places?\nThe value of pi to 4 decimal places is: 3.1416\nWhat is the value of pi to 5 decimal places?\nThe value of pi to 5 decimal places is: 3.14159\nWhat is'
